# %%
import pandas as pd
from matplotlib import pyplot as plt\

# %matplotlib inline
import optuna
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris

# %%
# data=pd.read_csv("C:\\Users\\hp\\OneDrive\\Documents\\logisticregression1.csv")
# data
data=load_iris()
x=data.data
y=data.target

# %%
#plt.scatter(data.Age,data.Purchased,marker='*',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
def objective(trail):
    c=trail.suggest_loguniform('c',1e-5,1e5)
    solver=trail.suggest_categorical('solver',['lbfgs','liblinear','saga'])
    max_iter=trail.suggest_int('max_iter',50,500)

    model=LogisticRegression(C=c,max_iter=max_iter,solver=solver,random_state=42)
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    accuracy=accuracy_score(y_test,y_pred)
    return accuracy

# %%
study=optuna.create_study(direction='maximize')
study.optimize(objective,n_trials=50)
# Out:
# [I 2025-03-02 21:27:52,353] A new study created in memory with name: no-name-0bace398-e259-43e7-bd5e-179f190d7fd8
# C:\Users\praja\AppData\Local\Temp\ipykernel_9884\4168705068.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c=trail.suggest_loguniform('c',1e-5,1e5)
# [I 2025-03-02 21:27:52,391] Trial 0 finished with value: 0.9 and parameters: {'c': 0.004399623477861191, 'solver': 'lbfgs', 'max_iter': 81}. Best is trial 0 with value: 0.9.
# C:\Users\praja\AppData\Local\Temp\ipykernel_9884\4168705068.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c=trail.suggest_loguniform('c',1e-5,1e5)
# ...

# %%
print(f"The balue:{study.best_trial.values}")
print(f"{study.best_trial.params}")
# Out:
# The balue:[1.0]
# {'c': 124.6186019546979, 'solver': 'saga', 'max_iter': 315}

# %%
from sklearn.linear_model import LogisticRegression

# %%
model2=LogisticRegression(C= 124.6186019546979, solver='saga', max_iter= 315,random_state=42)

# %%
model2.fit(x_train,y_train)
# Out:
# C:\Users\praja\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(C=124.6186019546979, max_iter=315, random_state=42,
#                    solver='saga')

# %%
y_pred=model2.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
#model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.8375

# %%
model.predict([[46]])
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
