# %%
import seaborn as sns
from sklearn import linear_model 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89      3.26
# 1  5.12      1.98
# 2  7.82      3.25
# 3  7.42      3.67
# 4  6.94      3.57

# %%
plt.scatter(x=df['cgpa'],y=df['package '])

# %%
x=df.iloc[:,[0]].values
y=df.iloc[:,[1]].values
y
# Out:
# array([[3.26],
#        [1.98],
#        [3.25],
#        [3.67],
#        [3.57],
#        [2.99],
#        [2.6 ],
#        [2.48],
#        [2.31],
#        [3.51],
#        [1.86],
#        [2.6 ],
#        [3.65],
#        [2.89],
#        [3.42],
#        [3.23],
#        [2.35],
#        [2.09],
#        [2.98]])

# %%
x
# Out:
# 0     6.89
# 1     5.12
# 2     7.82
# 3     7.42
# 4     6.94
# 5     7.89
# 6     6.73
# 7     6.75
# 8     6.09
# 9     8.31
# 10    5.32
# 11    6.61
# 12    8.94
# 13    6.93
# 14    7.73
# 15    7.25
# 16    6.84
# 17    5.38
# 18    6.94
# Name: cgpa, dtype: float64

# %%
y
# Out:
# 0     3.26
# 1     1.98
# 2     3.25
# 3     3.67
# 4     3.57
# 5     2.99
# 6     2.60
# 7     2.48
# 8     2.31
# 9     3.51
# 10    1.86
# 11    2.60
# 12    3.65
# 13    2.89
# 14    3.42
# 15    3.23
# 16    2.35
# 17    2.09
# 18    2.98
# Name: package , dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
reg=linear_model.LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([[2.85129396],
#        [3.38589719],
#        [2.70160506],
#        [1.90504625]])

# %%
reg.intercept_
# Out:
# array([-0.83212227])

# %%
reg.coef_
# Out:
# array([[0.53460323]])

# %%
class mylr:
    def __init__(self):
        self.m=None
        self.b=None
    def fit(self,x_train,y_train):
        x_train=x_train.reshape(1,-1)
        numerater=0
        denamenator=0
        for i in range(x_train.shape[0]):
            numerater=numerater+(y_train[i]-y_train.mean()*x_train[i]-x_train.mean())
            denamenator=denamenator+(x_train[i]-x_train.mean())
        

        self.m=numerater/denamenator

        self.b=self.b+y_train.mean()-(self.m*x_train.mean())
        print(self.b)

        
        
        
    def predict(self,x_test):
        pass
        
ob=mylr()
ob.fit(x_train,y_train)
ob.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 26
#      23         pass
#      25 ob=mylr()
# ---> 26 ob.fit(x_train,y_train)
#      27 ob.predict(x_test)
#
# Cell In[143], line 16, in mylr.fit(self, x_train, y_train)
#      11     denamenator=denamenator+(x_train[i]-x_train.mean())
#      14 self.m=numerater/denamenator
# ---> 16 self.b=self.b+y_train.mean()-(self.m*x_train.mean())
#      17 print(self.b)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'float'

# %%
x_train.shape,y_train.shape
# Out:
# ((15, 1), (15, 1))

# %%
x_train.reshape(1,-1).mean()
# Out:
# np.float64(7.026000000000001)

# %%
x_train.shape[0]
# Out:
# 15

# %%
#LinearRegressionUsing the TensorflowTutorial/
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Input

# %%
model=Sequential()
model.add(Dense(1,input_dim=(1)))
model.compile(optimizer='adagrad',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x,y,epochs=40,validation_data=(x,y),verbose=1)

history=model.history()
# Out:
# Epoch 1/40
# C:\Users\praja\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0000e+00 - loss: 46.3947 - val_accuracy: 0.0000e+00 - val_loss: 46.3947
# Epoch 2/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.0000e+00 - loss: 46.3947 - val_accuracy: 0.0000e+00 - val_loss: 46.3947
# Epoch 3/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.0000e+00 - loss: 46.3947 - val_accuracy: 0.0000e+00 - val_loss: 46.3947
# Epoch 4/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.0000e+00 - loss: 46.3947 - val_accuracy: 0.0000e+00 - val_loss: 46.3947
# Epoch 5/40
# ...

# %%
history=model.history
y_pred=model.predict(x)
from sklearn.metrics import accuracy_score,r2_score
r2_score(y,y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# -149.6266936259227

# %%
plt.scatter(x,y,color='g')
plt.plot(x,model.predict(x),color='red')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
